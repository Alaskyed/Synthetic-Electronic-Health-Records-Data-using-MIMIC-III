# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# ! pip install pgmpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Tempdatasets

# %%
# read csv file as dataframe, and drop ROW_ID column
def read_csv_no_rowid(file_path):
    df = pd.read_csv(file_path)
    df.drop(["Unnamed: 0", 'row_id'], axis=1, inplace=True)

    return df

# %%
# check NaN value

def nan_count(df):
    print("Total columns: " + str(len(df.columns)))
    print("Total rows: " + str(len(df)))
    print("--------------")
    print(df.isnull().sum())

# %%
nan_time = pd.to_datetime("2200-01-01 00:00:00")

# %% [markdown]
# ### Patients

# %%
random_patients_df = read_csv_no_rowid("../temp_sets/patients.csv")

# %%
# Drop useless colums
random_patients_df.drop(['dod', 'expire_flag'], axis=1, inplace=True)

# %%
# Transfer some date type

random_patients_df['dob'] = pd.to_datetime(random_patients_df['dob'])
# random_patients_df['DOD'] = pd.to_datetime(random_patients_df['DOD'])
random_patients_df['dod_hosp'] = pd.to_datetime(random_patients_df['dod_hosp'])
random_patients_df['dod_ssn'] = pd.to_datetime(random_patients_df['dod_ssn'])

# %%
nan_count(random_patients_df)
# Out:
# Total columns: 5
# Total rows: 1000
# --------------
# subject_id      0
# gender          0
# dob             0
# dod_hosp      774
# dod_ssn       702
# dtype: int64

# %%
random_patients_df['dob'].fillna(value=nan_time, inplace=True)
random_patients_df['dod_hosp'].fillna(value=nan_time, inplace=True)
random_patients_df['dod_ssn'].fillna(value=nan_time, inplace=True)

# %%
nan_count(random_patients_df)
# Out:
# Total columns: 5
# Total rows: 1000
# --------------
# subject_id    0
# gender        0
# dob           0
# dod_hosp      0
# dod_ssn       0
# dtype: int64

# %% [markdown]
# ### Admissions
#
# Note: the 'deathtime' in admission table cannot be dropped, as this column includes the exact time.

# %%
admissions_sample_df = read_csv_no_rowid("../temp_sets/admissions.csv")

# %%
admissions_sample_df.drop(['diagnosis'], axis=1, inplace=True)

# %%
admissions_sample_df['admittime'] = pd.to_datetime(admissions_sample_df['admittime'])
admissions_sample_df['dischtime'] = pd.to_datetime(admissions_sample_df['dischtime'])
admissions_sample_df['deathtime'] = pd.to_datetime(admissions_sample_df['deathtime'])
admissions_sample_df['edregtime'] = pd.to_datetime(admissions_sample_df['edregtime'])
admissions_sample_df['edouttime'] = pd.to_datetime(admissions_sample_df['edouttime'])

# %%
nan_count(admissions_sample_df)
# Out:
# Total columns: 17
# Total rows: 1289
# --------------
# subject_id                 0
# hadm_id                    0
# admittime                  0
# dischtime                  0
# deathtime               1159
# admission_type             0
# admission_location         0
# discharge_location         0
# insurance                  0
# language                 541
# religion                   8
# marital_status           219
# ethnicity                  0
# edregtime                604
# edouttime                604
# hospital_expire_flag       0
# has_chartevents_data       0
# dtype: int64

# %%
admissions_sample_df['deathtime'].fillna(value=nan_time, inplace=True)
admissions_sample_df['language'].fillna(value='unknow', inplace=True)
admissions_sample_df['marital_status'].fillna(value='unknow', inplace=True)
admissions_sample_df['edregtime'].fillna(value=nan_time, inplace=True)
admissions_sample_df['edouttime'].fillna(value=nan_time, inplace=True)
admissions_sample_df['religion'].fillna(value='unknow', inplace=True)

# %%
nan_count(admissions_sample_df)
# Out:
# Total columns: 17
# Total rows: 1289
# --------------
# subject_id              0
# hadm_id                 0
# admittime               0
# dischtime               0
# deathtime               0
# admission_type          0
# admission_location      0
# discharge_location      0
# insurance               0
# language                0
# religion                0
# marital_status          0
# ethnicity               0
# edregtime               0
# edouttime               0
# hospital_expire_flag    0
# has_chartevents_data    0
# dtype: int64

# %% [markdown]
# ### Callout

# %%
callout_sample_df = read_csv_no_rowid("../temp_sets/callout.csv")

# %%
callout_sample_df.drop(['submit_careunit', 'firstreservationtime', 'currentreservationtime'], axis=1, inplace=True)

# %%
callout_sample_df['acknowledgetime'] = pd.to_datetime(callout_sample_df['acknowledgetime'])

# %%
callout_sample_df.dtypes
# Out:
# subject_id                     int64
# hadm_id                        int64
# submit_wardid                  int64
# curr_wardid                    int64
# curr_careunit                 object
# callout_wardid                 int64
# callout_service               object
# request_tele                   int64
# request_resp                   int64
# request_cdiff                  int64
# request_mrsa                   int64
# request_vre                    int64
# callout_status                object
# callout_outcome               object
# discharge_wardid             float64
# acknowledge_status            object
# createtime                    object
# updatetime                    object
# acknowledgetime       datetime64[ns]
# outcometime                   object
# dtype: object

# %%
nan_count(callout_sample_df)
# Out:
# Total columns: 20
# Total rows: 807
# --------------
# subject_id              0
# hadm_id                 0
# submit_wardid           0
# curr_wardid             0
# curr_careunit           0
# callout_wardid          0
# callout_service         0
# request_tele            0
# request_resp            0
# request_cdiff           0
# request_mrsa            0
# request_vre             0
# callout_status          0
# callout_outcome         0
# discharge_wardid      119
# acknowledge_status      0
# createtime              0
# updatetime              0
# acknowledgetime        35
# outcometime             0
# dtype: int64

# %%
callout_sample_df['discharge_wardid'].fillna(value=100, inplace=True)
callout_sample_df['acknowledgetime'].fillna(value=nan_time, inplace=True)

# %%
nan_count(callout_sample_df)
# Out:
# Total columns: 20
# Total rows: 807
# --------------
# subject_id            0
# hadm_id               0
# submit_wardid         0
# curr_wardid           0
# curr_careunit         0
# callout_wardid        0
# callout_service       0
# request_tele          0
# request_resp          0
# request_cdiff         0
# request_mrsa          0
# request_vre           0
# callout_status        0
# callout_outcome       0
# discharge_wardid      0
# acknowledge_status    0
# createtime            0
# updatetime            0
# acknowledgetime       0
# outcometime           0
# dtype: int64

# %% [markdown]
# ### ICUstays

# %%
icustays_sample_df = read_csv_no_rowid("../temp_sets/icustays.csv")

# %%
icustays_sample_df['intime'] = pd.to_datetime(icustays_sample_df['intime'])
icustays_sample_df['outtime'] = pd.to_datetime(icustays_sample_df['outtime'])

# %%
nan_count(icustays_sample_df)
# Out:
# Total columns: 11
# Total rows: 1342
# --------------
# subject_id        0
# hadm_id           0
# icustay_id        0
# dbsource          0
# first_careunit    0
# last_careunit     0
# first_wardid      0
# last_wardid       0
# intime            0
# outtime           0
# los               0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Combine samples

# %%
patients_df = pd.merge(random_patients_df, admissions_sample_df, on=['subject_id'], how='inner')

# %%
nan_count(patients_df)
# Out:
# Total columns: 21
# Total rows: 1289
# --------------
# subject_id              0
# gender                  0
# dob                     0
# dod_hosp                0
# dod_ssn                 0
# hadm_id                 0
# admittime               0
# dischtime               0
# deathtime               0
# admission_type          0
# admission_location      0
# discharge_location      0
# insurance               0
# language                0
# religion                0
# marital_status          0
# ethnicity               0
# edregtime               0
# edouttime               0
# hospital_expire_flag    0
# has_chartevents_data    0
# dtype: int64

# %%
patients_df = pd.merge(patients_df, callout_sample_df, on=['subject_id', 'hadm_id'], how='inner')

# %%
nan_count(patients_df)
# Out:
# Total columns: 39
# Total rows: 807
# --------------
# subject_id              0
# gender                  0
# dob                     0
# dod_hosp                0
# dod_ssn                 0
# hadm_id                 0
# admittime               0
# dischtime               0
# deathtime               0
# admission_type          0
# admission_location      0
# discharge_location      0
# insurance               0
# language                0
# religion                0
# marital_status          0
# ethnicity               0
# edregtime               0
# edouttime               0
# hospital_expire_flag    0
# has_chartevents_data    0
# submit_wardid           0
# curr_wardid             0
# curr_careunit           0
# callout_wardid          0
# callout_service         0
# request_tele            0
# request_resp            0
# request_cdiff           0
# request_mrsa            0
# request_vre             0
# callout_status          0
# callout_outcome         0
# discharge_wardid        0
# acknowledge_status      0
# createtime              0
# updatetime              0
# acknowledgetime         0
# outcometime             0
# dtype: int64

# %%
patients_df = pd.merge(patients_df, icustays_sample_df.drop(['icustay_id', 'dbsource', 'first_careunit', 'last_careunit', 'first_wardid', \
                                                'last_wardid', 'intime', 'outtime', 'los'], axis=1), on=['subject_id', 'hadm_id'], how='inner')

# %%
nan_count(patients_df)
# Out:
# Total columns: 39
# Total rows: 992
# --------------
# subject_id              0
# gender                  0
# dob                     0
# dod_hosp                0
# dod_ssn                 0
# hadm_id                 0
# admittime               0
# dischtime               0
# deathtime               0
# admission_type          0
# admission_location      0
# discharge_location      0
# insurance               0
# language                0
# religion                0
# marital_status          0
# ethnicity               0
# edregtime               0
# edouttime               0
# hospital_expire_flag    0
# has_chartevents_data    0
# submit_wardid           0
# curr_wardid             0
# curr_careunit           0
# callout_wardid          0
# callout_service         0
# request_tele            0
# request_resp            0
# request_cdiff           0
# request_mrsa            0
# request_vre             0
# callout_status          0
# callout_outcome         0
# discharge_wardid        0
# acknowledge_status      0
# createtime              0
# updatetime              0
# acknowledgetime         0
# outcometime             0
# dtype: int64

# %%
# patients_df = pd.merge(patients_df, services_sample_df, on=['subject_id', 'hadm_id'], how='outer')
# patients_df = pd.merge(patients_df, transfers_sample_df.drop(['icustay_id', 'dbsource', 'curr_careunit', 'curr_wardid', \
#                                                 'intime', 'outtime', 'los'], axis=1), on=['subject_id', 'hadm_id'], how='outer')
# patients_df.fillna(value="Na", inplace=True)

# %%
nan_count(patients_df)
# Out:
# Total columns: 39
# Total rows: 992
# --------------
# subject_id              0
# gender                  0
# dob                     0
# dod_hosp                0
# dod_ssn                 0
# hadm_id                 0
# admittime               0
# dischtime               0
# deathtime               0
# admission_type          0
# admission_location      0
# discharge_location      0
# insurance               0
# language                0
# religion                0
# marital_status          0
# ethnicity               0
# edregtime               0
# edouttime               0
# hospital_expire_flag    0
# has_chartevents_data    0
# submit_wardid           0
# curr_wardid             0
# curr_careunit           0
# callout_wardid          0
# callout_service         0
# request_tele            0
# request_resp            0
# request_cdiff           0
# request_mrsa            0
# request_vre             0
# callout_status          0
# callout_outcome         0
# discharge_wardid        0
# acknowledge_status      0
# createtime              0
# updatetime              0
# acknowledgetime         0
# outcometime             0
# dtype: int64

# %%
patients_df.to_csv("patients_info.csv")

# %% [markdown]
# ---

# %% [markdown]
# ##  Build Network

# %%
# test_df.fillna(value="Na", inplace=True)

# %%
# from pgmpy.estimators import HillClimbSearch

# hc = HillClimbSearch(patients_df.loc[0:30, :])
# best_model = hc.estimate()
# print(best_model.edges())

# %% [markdown]
# [('subject_id', 'callout_service'), ('subject_id', 'religion'), ('subject_id', 'curr_wardid'), ('subject_id', 'dob'), ('dob', 'callout_wardid'), ('hadm_id', 'discharge_wardid'), ('hadm_id', 'dod_ssn'), ('admittime', 'marital_status'), ('admittime', 'deathtime'), ('deathtime', 'submit_wardid'), ('deathtime', 'ethnicity'), ('deathtime', 'hadm_id'), ('deathtime', 'dischtime'), ('marital_status', 'edregtime'), ('ethnicity', 'request_tele'), ('edregtime', 'dod_hosp'), ('edregtime', 'subject_id'), ('callout_wardid', 'updatetime'), ('request_tele', 'curr_careunit'), ('request_tele', 'edouttime'), ('createtime', 'outcometime'), ('updatetime', 'acknowledgetime'), ('updatetime', 'createtime')]

# %% [markdown]
# [('subject_id', 'marital_status'), ('subject_id', 'dob'), ('gender', 'insurance'), ('gender', 'admittime'), ('dob', 'request_tele'), ('dob', 'dod_ssn'), ('hadm_id', 'curr_wardid'), ('hadm_id', 'dod_hosp'), ('admittime', 'religion'), ('admittime', 'discharge_wardid'), ('admittime', 'hadm_id'), ('dischtime', 'callout_service'), ('deathtime', 'submit_wardid'), ('deathtime', 'callout_wardid'), ('admission_location', 'gender'), ('ethnicity', 'curr_careunit'), ('edregtime', 'ethnicity'), ('edregtime', 'dischtime'), ('curr_wardid', 'edouttime'), ('callout_wardid', 'updatetime'), ('callout_service', 'subject_id'), ('discharge_wardid', 'deathtime'), ('discharge_wardid', 'edregtime'), ('createtime', 'outcometime'), ('updatetime', 'createtime'), ('outcometime', 'acknowledgetime')]

# %%
from pgmpy.estimators import MmhcEstimator
from pgmpy.estimators import BDeuScore
from pgmpy.estimators import HillClimbSearch

# %%
patients_df.columns
# Out:
# Index(['subject_id', 'gender', 'dob', 'dod_hosp', 'dod_ssn', 'hadm_id',
#        'admittime', 'dischtime', 'deathtime', 'admission_type',
#        'admission_location', 'discharge_location', 'insurance', 'language',
#        'religion', 'marital_status', 'ethnicity', 'edregtime', 'edouttime',
#        'hospital_expire_flag', 'has_chartevents_data', 'submit_wardid',
#        'curr_wardid', 'curr_careunit', 'callout_wardid', 'callout_service',
#        'request_tele', 'request_resp', 'request_cdiff', 'request_mrsa',
#        'request_vre', 'callout_status', 'callout_outcome', 'discharge_wardid',
#        'acknowledge_status', 'createtime', 'updatetime', 'acknowledgetime',
#        'outcometime'],
#       dtype='object')

# %%
mmhc = MmhcEstimator(patients_df.loc[0:30, :])
skeleton = mmhc.mmpc()
print("Part 1) Skeleton: ", skeleton.edges())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\MSc Project\Synthetic-Electronic-Health-Records-Data-using-MIMIC-III\combine_datasets.ipynb Cell 51 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/f%3A/MSc%20Project/Synthetic-Electronic-Health-Records-Data-using-MIMIC-III/combine_datasets.ipynb#ch0000050?line=0'>1</a> mmhc = MmhcEstimator(patients_df.loc[0:30, :])
# ----> <a href='vscode-notebook-cell:/f%3A/MSc%20Project/Synthetic-Electronic-Health-Records-Data-using-MIMIC-III/combine_datasets.ipynb#ch0000050?line=1'>2</a> skeleton = mmhc.mmpc()
#       <a href='vscode-notebook-cell:/f%3A/MSc%20Project/Synthetic-Electronic-Health-Records-Data-using-MIMIC-III/combine_datasets.ipynb#ch0000050?line=2'>3</a> print("Part 1) Skeleton: ", skeleton.edges())
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\MmhcEstimator.py:189, in MmhcEstimator.mmpc(self, significance_level)
#     187 # Forward Phase
#     188 while True:
# --> 189     new_neighbor, new_neighbor_min_assoc = max_min_heuristic(
#     190         node, neighbors[node]
#     191     )
#     192     if new_neighbor_min_assoc > 0:
#     193         neighbors[node].append(new_neighbor)
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\MmhcEstimator.py:175, in MmhcEstimator.mmpc.<locals>.max_min_heuristic(X, Zs)
#     172 best_Y = None
#     174 for Y in set(nodes) - set(Zs + [X]):
# --> 175     min_assoc_val = min_assoc(X, Y, Zs)
#     176     if min_assoc_val >= max_min_assoc:
#     177         best_Y = Y
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\MmhcEstimator.py:167, in MmhcEstimator.mmpc.<locals>.min_assoc(X, Y, Zs)
#     165 def min_assoc(X, Y, Zs):
#     166     "Minimal association of X, Y given any subset of Zs."
# --> 167     return min(assoc(X, Y, Zs_subset) for Zs_subset in powerset(Zs))
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\MmhcEstimator.py:167, in <genexpr>(.0)
#     165 def min_assoc(X, Y, Zs):
#     166     "Minimal association of X, Y given any subset of Zs."
# --> 167     return min(assoc(X, Y, Zs_subset) for Zs_subset in powerset(Zs))
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\MmhcEstimator.py:163, in MmhcEstimator.mmpc.<locals>.assoc(X, Y, Zs)
#     159 def assoc(X, Y, Zs):
#     160     """Measure for (conditional) association between variables. Use negative
#     161     p-value of independence test.
#     162     """
# --> 163     return 1 - chi_square(X, Y, Zs, self.data, boolean=False)[1]
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\CITests.py:95, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      35 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      36     r"""
#      37     Chi-square conditional independence test.
#      38     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      93     False
#      94     """
# ---> 95     return power_divergence(
#      96         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      97     )
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\CITests.py:551, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     548 for z_state, df in data.groupby(Z):
#     549     try:
#     550         c, _, d, _ = stats.chi2_contingency(
# --> 551             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     552         )
#     553         chi += c
#     554         dof += d
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\groupby.py:2151, in GroupBy.size(self)
#    2138 @final
#    2139 @Substitution(name="groupby")
#    2140 @Appender(_common_see_also)
#    2141 def size(self) -> DataFrame | Series:
#    2142     """
#    2143     Compute group sizes.
#    2144
#    (...)
#    2149         or a DataFrame if as_index is False.
#    2150     """
# -> 2151     result = self.grouper.size()
#    2153     # GH28330 preserve subclassed Series/DataFrames through calls
#    2154     if isinstance(self.obj, Series):
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\ops.py:808, in BaseGrouper.size(self)
#     803 @final
#     804 def size(self) -> Series:
#     805     """
#     806     Compute group sizes.
#     807     """
# --> 808     ids, _, ngroups = self.group_info
#     809     out: np.ndarray | list
#     810     if ngroups:
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\ops.py:834, in BaseGrouper.group_info(self)
#     832 @cache_readonly
#     833 def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 834     comp_ids, obs_group_ids = self._get_compressed_codes()
#     836     ngroups = len(obs_group_ids)
#     837     comp_ids = ensure_platform_int(comp_ids)
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\ops.py:858, in BaseGrouper._get_compressed_codes(self)
#     854 @final
#     855 def _get_compressed_codes(self) -> tuple[np.ndarray, npt.NDArray[np.intp]]:
#     856     # The first returned ndarray may have any signed integer dtype
#     857     if len(self.groupings) > 1:
# --> 858         group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     859         return compress_group_index(group_index, sort=self._sort)
#     861     ping = self.groupings[0]
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\ops.py:793, in BaseGrouper.codes(self)
#     790 @final
#     791 @property
#     792 def codes(self) -> list[np.ndarray]:
# --> 793     return [ping.codes for ping in self.groupings]
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\ops.py:793, in <listcomp>(.0)
#     790 @final
#     791 @property
#     792 def codes(self) -> list[np.ndarray]:
# --> 793     return [ping.codes for ping in self.groupings]
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\grouper.py:622, in Grouping.codes(self)
#     618 if self._codes is not None:
#     619     # _codes is set in __init__ for MultiIndex cases
#     620     return self._codes
# --> 622 return self._codes_and_uniques[0]
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\groupby\grouper.py:690, in Grouping._codes_and_uniques(self)
#     688     else:
#     689         na_sentinel = -1
# --> 690     codes, uniques = algorithms.factorize(
#     691         self.grouping_vector, sort=self._sort, na_sentinel=na_sentinel
#     692     )
#     693 return codes, uniques
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\algorithms.py:768, in factorize(values, sort, na_sentinel, size_hint)
#     763     codes, uniques = factorize_array(
#     764         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     765     )
#     767 if sort and len(uniques) > 0:
# --> 768     uniques, codes = safe_sort(
#     769         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     770     )
#     772 code_is_na = codes == na_sentinel
#     773 if not dropna and code_is_na.any():
#     774     # na_value is set based on the dtype of uniques, and compat set to False is
#     775     # because we do not want na_value to be 0 for integers
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pandas\core\algorithms.py:1736, in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    1734 try:
#    1735     sorter = values.argsort()
# -> 1736     ordered = values.take(sorter)
#    1737 except TypeError:
#    1738     # Previous sorters failed or were not applicable, try `_sort_mixed`
#    1739     # which would work, but which fails for special case of 1d arrays
#    1740     # with tuples.
#    1741     if values.size and isinstance(values[0], tuple):
#
# KeyboardInterrupt:

# %%
hc = HillClimbSearch(patients_df.loc[0:30, :])
model = hc.estimate(tabu_length=10, white_list=skeleton.to_directed().edges())
print("Part 2) Model:    ", model.edges())
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# Part 2) Model:     []

# %% [markdown]
# ## Generation test

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import BayesianEstimator
from pgmpy.sampling import BayesianModelSampling

# %%
my_model = BayesianNetwork(model.edges())

# %%
my_model.fit(patients_df, estimator=BayesianEstimator, prior_type="BDeu") # default equivalent_sample_size=5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\MSc Project\Synthetic-Electronic-Health-Records-Data-using-MIMIC-III\combine_datasets.ipynb Cell 57 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/f%3A/MSc%20Project/Synthetic-Electronic-Health-Records-Data-using-MIMIC-III/combine_datasets.ipynb#ch0000061?line=0'>1</a> my_model.fit(callout_sample_df, estimator=BayesianEstimator, prior_type="BDeu")
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\models\BayesianNetwork.py:580, in BayesianNetwork.fit(self, data, estimator, state_names, complete_samples_only, n_jobs, **kwargs)
#     577     if not issubclass(estimator, BaseEstimator):
#     578         raise TypeError("Estimator object should be a valid pgmpy estimator.")
# --> 580 _estimator = estimator(
#     581     self,
#     582     data,
#     583     state_names=state_names,
#     584     complete_samples_only=complete_samples_only,
#     585 )
#     586 cpds_list = _estimator.get_parameters(n_jobs=n_jobs, **kwargs)
#     587 self.add_cpds(*cpds_list)
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\BayesianEstimator.py:30, in BayesianEstimator.__init__(self, model, data, **kwargs)
#      25 elif len(model.latents) != 0:
#      26     raise ValueError(
#      27         f"Bayesian Parameter Estimation works only on models with all observed variables. Found latent variables: {model.latents}"
#      28     )
# ---> 30 super(BayesianEstimator, self).__init__(model, data, **kwargs)
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\estimators\base.py:209, in ParameterEstimator.__init__(self, model, data, **kwargs)
#     183 """
#     184 Base class for parameter estimators in pgmpy.
#     185
#    (...)
#     205     This sets the behavior of the `state_count`-method.
#     206 """
#     208 if not (set(model.nodes()) - model.latents) <= set(data.columns.values):
# --> 209     raise ValueError(
#     210         "variable names of the model must be identical to column names in data"
#     211     )
#     212 self.model = model
#     214 super(ParameterEstimator, self).__init__(data, **kwargs)
#
# ValueError: variable names of the model must be identical to column names in data

# %%
# my_model.fit(callout_sample_df, estimator=BayesianEstimator, prior_type="BDeu") # default equivalent_sample_size=5
# for cpd in my_model.get_cpds():
#     print(cpd)
# Out:
# +-------------------+-----+------------------------+
# | callout_service   | ... | callout_service(VSURG) |
# +-------------------+-----+------------------------+
# | subject_id(68)    | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(145)   | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(969)   | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(998)   | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1108)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1286)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1354)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1404)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1679)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1820)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(1944)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(2021)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(2361)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(2377)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(2574)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(2723)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(2791)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(3084)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(3101)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(3482)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(3790)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(3954)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(3982)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(4072)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(4394)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(4458)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(4676)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(4784)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(4873)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(5071)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(5211)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(5360)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(5573)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(5868)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(6166)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(6170)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(6457)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(6598)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7052)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7296)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7340)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7380)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7656)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7715)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(7825)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8296)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8393)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8517)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8532)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8559)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8675)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(8731)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9052)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9216)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9272)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9277)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9369)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9417)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9432)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9474)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9486)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9517)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(9908)  | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(10224) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(10424) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(10498) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(10614) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(10780) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(10814) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(11133) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(11218) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(11343) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(11437) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(11516) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(11607) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(12073) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(12252) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(12373) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(13167) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(13177) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(13419) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(13753) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(14038) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(14297) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(14777) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(14936) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(16087) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(16286) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(16344) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(16679) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(16816) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(17008) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(17135) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(17310) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(17621) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(18211) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(18231) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(18846) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(19303) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19361) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19529) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19536) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19599) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19635) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19876) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(19894) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(20226) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(20553) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(21557) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(21599) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(21691) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(21926) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(21975) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(22126) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(22166) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(22180) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(22243) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(22419) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(22464) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(22919) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(23365) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(23457) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(23604) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(23754) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(23962) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24094) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24193) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24424) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24492) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24682) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24743) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24774) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(24952) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(25272) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(25326) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(25574) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(26005) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(26473) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(26848) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(26935) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(26997) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(27128) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27175) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27206) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27225) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27323) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27355) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27367) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27378) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27593) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27697) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27795) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27981) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(27996) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28021) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28058) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28065) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28141) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28166) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28250) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28293) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28326) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28410) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28479) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(28500) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28506) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28584) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28601) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(28819) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29045) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29056) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29074) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29155) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29209) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29219) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29294) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29431) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29458) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29538) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29609) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29612) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29645) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29651) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29652) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29749) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29779) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29836) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29947) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29971) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(29988) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30020) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30050) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30141) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30299) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30319) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30607) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30650) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30775) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30927) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(30930) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31004) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31045) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31062) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31134) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31171) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31187) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31191) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31293) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31342) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31379) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31389) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31438) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31777) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31778) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31814) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31840) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31852) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(31993) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32046) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32247) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32380) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32421) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32578) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32674) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32726) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(32730) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(40094) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(40321) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(40686) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(40991) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(41013) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(41107) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(41302) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(41328) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(41447) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(42055) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(42261) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(42444) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(42683) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(42820) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(43047) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(43269) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(43322) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(43323) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(43459) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(43942) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(44023) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(44894) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(45108) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(45124) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(45329) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(45583) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(45689) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(46114) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(46498) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(47277) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(47445) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(47715) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(47747) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(47759) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48036) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48521) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48637) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48640) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48736) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48806) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48826) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(48982) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(49202) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(49205) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(49265) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(49480) | ... | 0.1226446203127945     |
# +-------------------+-----+------------------------+
# | subject_id(50302) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(50549) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(50877) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51045) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51104) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51178) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51327) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51364) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51404) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51874) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(51966) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(52038) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(52078) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(52248) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(52815) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(52990) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(53417) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(53470) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(53772) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(53787) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(54056) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(54268) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(54577) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(54600) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(54620) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(54661) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(55272) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(55456) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(55729) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(55921) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56042) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56279) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56307) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56333) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56339) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56391) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56589) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56613) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56734) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56900) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(56960) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(57233) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(57619) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(57737) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(57764) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(57865) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(57904) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(58134) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(58417) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(58843) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(58899) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(59053) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(59094) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(59844) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(59941) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60030) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60048) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60083) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60139) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60195) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60572) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60767) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60798) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60954) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(60977) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(61223) | ... | 0.0613419383204573     |
# +-------------------+-----+------------------------+
# | subject_id(61450) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(61568) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(61636) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(61638) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(61816) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(61998) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(62187) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(62515) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(62530) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(62764) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(62801) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(62950) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(63298) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(63841) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(64145) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(64759) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(64921) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(65278) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(65401) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(65467) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(65682) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(66093) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(66174) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(66534) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(66662) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(66892) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(67032) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(67139) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(67154) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(67680) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(68275) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(68530) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(68676) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(69359) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(70104) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(70641) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(71129) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(71564) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(71735) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(71812) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(72043) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(72224) | ... | 0.1226446203127945     |
# +-------------------+-----+------------------------+
# | subject_id(72248) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(72666) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(72751) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(73059) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(73398) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(73417) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(73652) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(73790) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(75500) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(75582) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(75591) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(76536) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(76915) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(77084) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(77678) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(77799) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(77819) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(78015) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(78155) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(78678) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(78797) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(78966) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(79061) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(79423) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(79465) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(79578) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(79754) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(79878) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(80158) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(80294) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(80588) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(80844) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(80956) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(80963) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(81096) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(81111) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(81280) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(81349) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(81787) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(82159) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(82605) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(83599) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(83670) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(83746) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(83988) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(84437) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(84523) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(84718) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(85245) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(85516) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(85541) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(85866) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(85980) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(86108) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(86381) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(86531) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(86934) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(87172) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(87217) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(87459) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(87470) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(87692) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(87847) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(88009) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(88012) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(88202) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(88657) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(88660) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(89132) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(89297) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# | subject_id(89404) | ... | 3.9256328120092984e-05 |
# +-------------------+-----+------------------------+
# ...
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 7.976211746088465e-06            |
# +-----+----------------------------------+
# | ... | 0.9938503407437658               |
# +-----+----------------------------------+

# %%
from pgmpy.sampling import BayesianModelSampling

# %%
samples = BayesianModelSampling(my_model).forward_sample(size=int(500))
samples.head()
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# d:\Environment\anaconda3\envs\msc_project\lib\site-packages\pgmpy\utils\mathext.py:83: UserWarning: Probability values don't exactly sum to 1. Differ by: 3.3306690738754696e-16. Adjusting values.
#   warn(
#    subject_id  hadm_id           createtime  submit_wardid curr_careunit  \
# 0       47715   170400  2121-03-09 10:48:49             23          MICU
# 1        7715   192622  2111-09-16 10:25:34              7           CCU
# 2       88009   109037  2188-03-16 09:20:55             57          SICU
# 3       90508   103295  2195-07-07 12:03:53             50          MICU
# 4       32380   159188  2112-03-01 12:02:55             23          MICU
#
#    request_tele  curr_wardid  discharge_wardid  callout_wardid  \
# 0             1           17               9.0              17
# 1             1           45              45.0               1
# 2             1           29               0.0               1
# 3             1           45              45.0               1
# 4             0           17               9.0               1
#
#   callout_service          outcometime           updatetime  \
# 0             CCU  2121-03-09 17:40:30  2121-03-09 10:48:49
# 1             MED  2111-09-16 16:27:16  2111-09-16 11:21:58
# 2             MED  2188-03-16 22:40:23  2188-03-16 09:20:55
# 3             MED  2195-07-07 16:40:22  2195-07-07 12:03:53
# 4            CMED  2112-03-01 19:27:57  2112-03-01 12:02:55
#
#        acknowledgetime
# 0  2121-03-09 10:58:24
# 1  2111-09-16 11:37:10
# 2  2188-03-16 09:23:27
# 3  2195-07-07 12:37:10
# 4  2112-03-01 13:00:22

# %%
# samples.to_csv("samples.csv")

# %%
nan_count(samples)
# Out:
# Total columns: 13
# Total rows: 100000
# --------------
# subject_id          0
# hadm_id             0
# createtime          0
# submit_wardid       0
# curr_careunit       0
# request_tele        0
# curr_wardid         0
# discharge_wardid    0
# callout_wardid      0
# callout_service     0
# outcometime         0
# updatetime          0
# acknowledgetime     0
# dtype: int64
