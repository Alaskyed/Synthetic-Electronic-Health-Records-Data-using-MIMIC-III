# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# ! pip install sdv

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
# read csv file as dataframe, and drop ROW_ID column
def read_csv_no_rowid(file_path):
    df = pd.read_csv(file_path)
    df.drop(["Unnamed: 0", 'row_id'], axis=1, inplace=True)

    return df

# %%
# check NaN value

def nan_count(df):
    print("Total columns: " + str(len(df.columns)))
    print("Total rows: " + str(len(df)))
    print("--------------")
    print(df.isnull().sum())

# %%
date_set_path = "../temp_sets_100/"

# %%
procedures_icd_sample_df = read_csv_no_rowid(date_set_path + "procedures_icd.csv")

# %%
procedures_icd_sample_df
# Out:
#      subject_id  hadm_id  seq_num  icd9_code
# 0           569   116412        1         66
# 1           569   116412        2       3607
# 2           569   116412        3         46
# 3           569   116412        4         41
# 4           569   116412        5       3723
# ..          ...      ...      ...        ...
# 485       26884   123835        2       8851
# 486       49024   182358        1       9910
# 487       15440   158614        1       3511
# 488       15440   158614        2       3844
# 489       15440   158614        3       3961
#
# [490 rows x 4 columns]

# %%
procedures_icd_sample_df.dropna(subset=['hadm_id'], inplace=True, axis=0)

# %%
nan_count(procedures_icd_sample_df)
# Out:
# Total columns: 4
# Total rows: 490
# --------------
# subject_id    0
# hadm_id       0
# seq_num       0
# icd9_code     0
# dtype: int64

# %%
nan_count(procedures_icd_sample_df)
# Out:
# Total columns: 4
# Total rows: 490
# --------------
# subject_id    0
# hadm_id       0
# seq_num       0
# icd9_code     0
# dtype: int64

# %%
# Set columns' type
# procedures_icd_sample_df['subject_id'] = procedures_icd_sample_df['subject_id'].astype(str)
# procedures_icd_sample_df['hadm_id'] = procedures_icd_sample_df['hadm_id'].astype(str)

# procedures_icd_sample_df['icd9_code'] = procedures_icd_sample_df['icd9_code'].astype(str)

# %%
procedures_icd_sample_df.dtypes
# Out:
# subject_id    int64
# hadm_id       int64
# seq_num       int64
# icd9_code     int64
# dtype: object

# %%
len(procedures_icd_sample_df)
# Out:
# 490

# %% [markdown]
# ---

# %% [markdown]
# ## Build model

# %%
from sdv.tabular import CTGAN
from sdv.evaluation import evaluate
from sdv.constraints import FixedCombinations

# %%
procedures_icd_sample_df.columns
# Out:
# Index(['subject_id', 'hadm_id', 'seq_num', 'icd9_code'], dtype='object')

# %%
fixed_subject_hadm_icustay_constraint = FixedCombinations(
    column_names=['subject_id', 'hadm_id']
)

# %%
procedures_icd_constraints = [fixed_subject_hadm_icustay_constraint]

# %%
model = CTGAN(
    constraints=procedures_icd_constraints, 
    generator_lr=0.0005,
    batch_size=1000,
    cuda=True, 
    verbose=True, 
    epochs=150)

# %%
len(procedures_icd_sample_df)
# Out:
# 490

# %%
train_data = procedures_icd_sample_df
model.fit(train_data)
# Out:
# Epoch 1, Loss G:  4.8260,Loss D:  0.0024
# Epoch 2, Loss G:  4.8250,Loss D: -0.0026
# Epoch 3, Loss G:  4.7827,Loss D:  0.0010
# Epoch 4, Loss G:  4.7948,Loss D:  0.0017
# Epoch 5, Loss G:  4.7395,Loss D: -0.0120
# Epoch 6, Loss G:  4.7073,Loss D: -0.0136
# Epoch 7, Loss G:  4.7086,Loss D: -0.0141
# Epoch 8, Loss G:  4.6863,Loss D: -0.0087
# Epoch 9, Loss G:  4.6682,Loss D: -0.0128
# Epoch 10, Loss G:  4.6556,Loss D: -0.0183
# Epoch 11, Loss G:  4.6111,Loss D: -0.0050
# Epoch 12, Loss G:  4.5838,Loss D:  0.0055
# Epoch 13, Loss G:  4.5839,Loss D: -0.0146
# Epoch 14, Loss G:  4.5740,Loss D: -0.0084
# Epoch 15, Loss G:  4.5585,Loss D:  0.0080
# Epoch 16, Loss G:  4.5215,Loss D: -0.0139
# Epoch 17, Loss G:  4.5209,Loss D:  0.0145
# Epoch 18, Loss G:  4.4911,Loss D:  0.0196
# Epoch 19, Loss G:  4.4448,Loss D:  0.0250
# Epoch 20, Loss G:  4.4355,Loss D:  0.0367
# Epoch 21, Loss G:  4.3870,Loss D:  0.0865
# Epoch 22, Loss G:  4.4498,Loss D:  0.0581
# Epoch 23, Loss G:  4.4186,Loss D:  0.0410
# Epoch 24, Loss G:  4.4437,Loss D:  0.0213
# Epoch 25, Loss G:  4.4360,Loss D:  0.0317
# Epoch 26, Loss G:  4.4513,Loss D: -0.0117
# Epoch 27, Loss G:  4.4757,Loss D: -0.0040
# Epoch 28, Loss G:  4.4450,Loss D: -0.0187
# Epoch 29, Loss G:  4.4297,Loss D: -0.0080
# Epoch 30, Loss G:  4.4197,Loss D: -0.0234
# Epoch 31, Loss G:  4.3591,Loss D:  0.0092
# Epoch 32, Loss G:  4.3371,Loss D: -0.0004
# Epoch 33, Loss G:  4.2994,Loss D:  0.0441
# Epoch 34, Loss G:  4.2864,Loss D:  0.0714
# Epoch 35, Loss G:  4.2639,Loss D:  0.0573
# Epoch 36, Loss G:  4.3194,Loss D:  0.0382
# Epoch 37, Loss G:  4.2732,Loss D:  0.0197
# Epoch 38, Loss G:  4.2629,Loss D:  0.0014
# Epoch 39, Loss G:  4.2662,Loss D: -0.0136
# Epoch 40, Loss G:  4.2821,Loss D: -0.0267
# Epoch 41, Loss G:  4.3341,Loss D: -0.0142
# Epoch 42, Loss G:  4.2638,Loss D: -0.0692
# Epoch 43, Loss G:  4.2861,Loss D: -0.0636
# Epoch 44, Loss G:  4.2606,Loss D: -0.0403
# Epoch 45, Loss G:  4.2643,Loss D: -0.0717
# Epoch 46, Loss G:  4.2407,Loss D: -0.0596
# Epoch 47, Loss G:  4.1996,Loss D: -0.0379
# Epoch 48, Loss G:  4.1614,Loss D:  0.0068
# Epoch 49, Loss G:  4.0986,Loss D:  0.0122
# Epoch 50, Loss G:  4.0573,Loss D:  0.0488
# Epoch 51, Loss G:  4.0295,Loss D:  0.0965
# Epoch 52, Loss G:  3.9930,Loss D:  0.0879
# Epoch 53, Loss G:  3.9903,Loss D:  0.1150
# Epoch 54, Loss G:  3.9360,Loss D:  0.1241
# Epoch 55, Loss G:  3.8839,Loss D:  0.1246
# Epoch 56, Loss G:  3.9393,Loss D:  0.1510
# Epoch 57, Loss G:  3.8998,Loss D:  0.1204
# Epoch 58, Loss G:  3.9119,Loss D:  0.0811
# Epoch 59, Loss G:  3.9014,Loss D:  0.0727
# Epoch 60, Loss G:  3.9128,Loss D:  0.0452
# Epoch 61, Loss G:  3.9340,Loss D: -0.0031
# Epoch 62, Loss G:  3.9232,Loss D: -0.0268
# Epoch 63, Loss G:  3.9150,Loss D: -0.0535
# Epoch 64, Loss G:  3.8954,Loss D: -0.0640
# Epoch 65, Loss G:  3.9110,Loss D: -0.0673
# Epoch 66, Loss G:  3.8818,Loss D: -0.1072
# Epoch 67, Loss G:  3.8801,Loss D: -0.1049
# Epoch 68, Loss G:  3.8421,Loss D: -0.0965
# Epoch 69, Loss G:  3.8297,Loss D: -0.1159
# Epoch 70, Loss G:  3.7711,Loss D: -0.0795
# Epoch 71, Loss G:  3.7052,Loss D: -0.0611
# Epoch 72, Loss G:  3.6800,Loss D: -0.0579
# Epoch 73, Loss G:  3.6276,Loss D: -0.0228
# Epoch 74, Loss G:  3.5837,Loss D: -0.0087
# Epoch 75, Loss G:  3.5299,Loss D:  0.0224
# Epoch 76, Loss G:  3.5211,Loss D:  0.0237
# Epoch 77, Loss G:  3.4649,Loss D:  0.0451
# Epoch 78, Loss G:  3.4300,Loss D:  0.0421
# Epoch 79, Loss G:  3.4035,Loss D:  0.0473
# Epoch 80, Loss G:  3.3949,Loss D:  0.0282
# Epoch 81, Loss G:  3.3053,Loss D:  0.0282
# Epoch 82, Loss G:  3.2762,Loss D:  0.0337
# Epoch 83, Loss G:  3.2871,Loss D:  0.0354
# Epoch 84, Loss G:  3.2707,Loss D:  0.0211
# Epoch 85, Loss G:  3.1584,Loss D:  0.0170
# Epoch 86, Loss G:  3.2259,Loss D:  0.0032
# Epoch 87, Loss G:  3.1242,Loss D:  0.0133
# Epoch 88, Loss G:  3.1201,Loss D:  0.0082
# Epoch 89, Loss G:  3.0271,Loss D:  0.0190
# Epoch 90, Loss G:  2.9828,Loss D: -0.0030
# Epoch 91, Loss G:  2.8398,Loss D:  0.0465
# Epoch 92, Loss G:  2.7774,Loss D:  0.0701
# Epoch 93, Loss G:  2.7555,Loss D:  0.0748
# Epoch 94, Loss G:  2.7183,Loss D:  0.0944
# Epoch 95, Loss G:  2.6560,Loss D:  0.0784
# Epoch 96, Loss G:  2.5270,Loss D:  0.1094
# Epoch 97, Loss G:  2.4872,Loss D:  0.1147
# Epoch 98, Loss G:  2.4483,Loss D:  0.1008
# Epoch 99, Loss G:  2.4133,Loss D:  0.0572
# Epoch 100, Loss G:  2.3654,Loss D:  0.0562
# Epoch 101, Loss G:  2.3893,Loss D:  0.0129
# Epoch 102, Loss G:  2.3648,Loss D: -0.0183
# Epoch 103, Loss G:  2.3425,Loss D: -0.0370
# Epoch 104, Loss G:  2.3124,Loss D: -0.0790
# Epoch 105, Loss G:  2.2477,Loss D: -0.0974
# Epoch 106, Loss G:  2.1819,Loss D: -0.0923
# Epoch 107, Loss G:  2.1145,Loss D: -0.1200
# Epoch 108, Loss G:  2.0157,Loss D: -0.1187
# Epoch 109, Loss G:  1.9922,Loss D: -0.1041
# Epoch 110, Loss G:  1.8876,Loss D: -0.1077
# Epoch 111, Loss G:  1.9031,Loss D: -0.1052
# Epoch 112, Loss G:  1.7242,Loss D: -0.0911
# Epoch 113, Loss G:  1.6137,Loss D: -0.0686
# Epoch 114, Loss G:  1.5543,Loss D: -0.0590
# Epoch 115, Loss G:  1.4802,Loss D: -0.0184
# Epoch 116, Loss G:  1.4202,Loss D: -0.0253
# Epoch 117, Loss G:  1.3150,Loss D:  0.0433
# Epoch 118, Loss G:  1.2696,Loss D:  0.0750
# Epoch 119, Loss G:  1.1654,Loss D:  0.0111
# Epoch 120, Loss G:  1.1205,Loss D:  0.0260
# Epoch 121, Loss G:  1.1103,Loss D:  0.0477
# Epoch 122, Loss G:  1.0587,Loss D:  0.0635
# Epoch 123, Loss G:  0.9510,Loss D:  0.0620
# Epoch 124, Loss G:  0.9127,Loss D:  0.0550
# Epoch 125, Loss G:  0.8259,Loss D:  0.0561
# Epoch 126, Loss G:  0.7870,Loss D:  0.0798
# Epoch 127, Loss G:  0.7316,Loss D:  0.0970
# Epoch 128, Loss G:  0.7219,Loss D:  0.0494
# Epoch 129, Loss G:  0.6767,Loss D:  0.0825
# Epoch 130, Loss G:  0.6594,Loss D:  0.0484
# Epoch 131, Loss G:  0.5875,Loss D:  0.0616
# Epoch 132, Loss G:  0.5870,Loss D:  0.0841
# Epoch 133, Loss G:  0.4928,Loss D:  0.0460
# Epoch 134, Loss G:  0.4782,Loss D:  0.0527
# Epoch 135, Loss G:  0.4601,Loss D:  0.0235
# Epoch 136, Loss G:  0.4656,Loss D:  0.0784
# Epoch 137, Loss G:  0.3775,Loss D:  0.0466
# Epoch 138, Loss G:  0.3738,Loss D:  0.0789
# Epoch 139, Loss G:  0.3190,Loss D:  0.0586
# Epoch 140, Loss G:  0.3436,Loss D:  0.0807
# Epoch 141, Loss G:  0.2732,Loss D:  0.0707
# Epoch 142, Loss G:  0.2358,Loss D:  0.0325
# Epoch 143, Loss G:  0.2437,Loss D:  0.0081
# Epoch 144, Loss G:  0.2453,Loss D:  0.0049
# Epoch 145, Loss G:  0.2296,Loss D:  0.0190
# Epoch 146, Loss G:  0.1893,Loss D: -0.0463
# Epoch 147, Loss G:  0.1724,Loss D: -0.0219
# Epoch 148, Loss G:  0.1591,Loss D: -0.0333
# Epoch 149, Loss G:  0.1992,Loss D: -0.0746
# Epoch 150, Loss G:  0.1567,Loss D: -0.0818

# %%
model.save(date_set_path + "100_models/" + "procedures_icd_model.pkl")

# %%
# model = CTGAN.load(("/content/drive/MyDrive/MSc Project/procedures_icd_model.pkl"))

# %%
sample = model.sample(num_rows=len(train_data))
# Out:
# Sampling rows: 100%|██████████| 490/490 [00:00<00:00, 12699.80it/s]

# %%
nan_count(sample)
# Out:
# Total columns: 4
# Total rows: 490
# --------------
# subject_id    0
# hadm_id       0
# seq_num       0
# icd9_code     0
# dtype: int64

# %%
sample.dtypes
# Out:
# subject_id    int64
# hadm_id       int64
# seq_num       int64
# icd9_code     int64
# dtype: object

# %%
evaluate(sample, train_data, metrics=['ContinuousKLDivergence'])
# Out:
# 0.489854202279242

# %%
evaluate(sample, train_data, metrics=['DiscreteKLDivergence'])
# Out:
# nan
