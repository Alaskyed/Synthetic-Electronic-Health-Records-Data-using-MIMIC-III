# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# ! pip install sdv

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
# read csv file as dataframe, and drop ROW_ID column
def read_csv_no_rowid(file_path):
    df = pd.read_csv(file_path)
    df.drop(["Unnamed: 0", 'row_id'], axis=1, inplace=True)

    return df

# %%
# check NaN value

def nan_count(df):
    print("Total columns: " + str(len(df.columns)))
    print("Total rows: " + str(len(df)))
    print("--------------")
    print(df.isnull().sum())

# %%
date_set_path = "../temp_sets_100/"

# %%
procedures_icd_sample_df = read_csv_no_rowid(date_set_path + "procedures_icd.csv")

# %%
procedures_icd_sample_df
# Out:
#      subject_id  hadm_id  seq_num  icd9_code
# 0           569   116412        1         66
# 1           569   116412        2       3607
# 2           569   116412        3         46
# 3           569   116412        4         41
# 4           569   116412        5       3723
# ..          ...      ...      ...        ...
# 485       26884   123835        2       8851
# 486       49024   182358        1       9910
# 487       15440   158614        1       3511
# 488       15440   158614        2       3844
# 489       15440   158614        3       3961
#
# [490 rows x 4 columns]

# %%
procedures_icd_sample_df.dropna(subset=['hadm_id'], inplace=True, axis=0)

# %%
nan_count(procedures_icd_sample_df)
# Out:
# Total columns: 4
# Total rows: 490
# --------------
# subject_id    0
# hadm_id       0
# seq_num       0
# icd9_code     0
# dtype: int64

# %%
nan_count(procedures_icd_sample_df)
# Out:
# Total columns: 4
# Total rows: 490
# --------------
# subject_id    0
# hadm_id       0
# seq_num       0
# icd9_code     0
# dtype: int64

# %%
# Set columns' type
# procedures_icd_sample_df['subject_id'] = procedures_icd_sample_df['subject_id'].astype(str)
# procedures_icd_sample_df['hadm_id'] = procedures_icd_sample_df['hadm_id'].astype(str)

# procedures_icd_sample_df['icd9_code'] = procedures_icd_sample_df['icd9_code'].astype(str)

# %%
procedures_icd_sample_df.dtypes
# Out:
# subject_id    int64
# hadm_id       int64
# seq_num       int64
# icd9_code     int64
# dtype: object

# %%
len(procedures_icd_sample_df)
# Out:
# 490

# %% [markdown]
# ---

# %% [markdown]
# ## Build model

# %%
from sdv.tabular import CTGAN
from sdv.evaluation import evaluate
from sdv.constraints import FixedCombinations

# %%
procedures_icd_sample_df.columns
# Out:
# Index(['subject_id', 'hadm_id', 'seq_num', 'icd9_code'], dtype='object')

# %%
fixed_subject_hadm_icustay_constraint = FixedCombinations(
    column_names=['subject_id', 'hadm_id']
)

# %%
procedures_icd_constraints = [fixed_subject_hadm_icustay_constraint]

# %%
model = CTGAN(
    constraints=procedures_icd_constraints, 
    generator_lr=0.0005,
    batch_size=1000,
    cuda=True, 
    verbose=True, 
    epochs=150)

# %%
len(procedures_icd_sample_df)
# Out:
# 490

# %%
train_data = procedures_icd_sample_df
model.fit(train_data)
# Out:
# Epoch 1, Loss G:  4.7871,Loss D: -0.0024
# Epoch 2, Loss G:  4.7621,Loss D: -0.0018
# Epoch 3, Loss G:  4.7448,Loss D: -0.0035
# Epoch 4, Loss G:  4.6804,Loss D: -0.0065
# Epoch 5, Loss G:  4.6998,Loss D: -0.0085
# Epoch 6, Loss G:  4.6838,Loss D: -0.0144
# Epoch 7, Loss G:  4.6469,Loss D: -0.0096
# Epoch 8, Loss G:  4.6291,Loss D: -0.0054
# Epoch 9, Loss G:  4.6166,Loss D:  0.0046
# Epoch 10, Loss G:  4.5862,Loss D:  0.0135
# Epoch 11, Loss G:  4.5859,Loss D:  0.0036
# Epoch 12, Loss G:  4.5477,Loss D:  0.0356
# Epoch 13, Loss G:  4.5561,Loss D:  0.0041
# Epoch 14, Loss G:  4.5378,Loss D:  0.0214
# Epoch 15, Loss G:  4.5235,Loss D:  0.0293
# Epoch 16, Loss G:  4.5102,Loss D:  0.0347
# Epoch 17, Loss G:  4.5133,Loss D:  0.0085
# Epoch 18, Loss G:  4.4982,Loss D:  0.0287
# Epoch 19, Loss G:  4.4983,Loss D:  0.0388
# Epoch 20, Loss G:  4.5052,Loss D:  0.0232
# Epoch 21, Loss G:  4.4459,Loss D:  0.0039
# Epoch 22, Loss G:  4.4578,Loss D:  0.0225
# Epoch 23, Loss G:  4.4790,Loss D: -0.0236
# Epoch 24, Loss G:  4.4823,Loss D: -0.0027
# Epoch 25, Loss G:  4.4515,Loss D: -0.0317
# Epoch 26, Loss G:  4.4642,Loss D: -0.0300
# Epoch 27, Loss G:  4.4602,Loss D: -0.0088
# Epoch 28, Loss G:  4.3887,Loss D:  0.0110
# Epoch 29, Loss G:  4.3810,Loss D: -0.0087
# Epoch 30, Loss G:  4.3846,Loss D:  0.0447
# Epoch 31, Loss G:  4.3264,Loss D:  0.0192
# Epoch 32, Loss G:  4.3217,Loss D:  0.0453
# Epoch 33, Loss G:  4.2737,Loss D:  0.0402
# Epoch 34, Loss G:  4.3262,Loss D:  0.0419
# Epoch 35, Loss G:  4.2790,Loss D:  0.0247
# Epoch 36, Loss G:  4.2725,Loss D:  0.0301
# Epoch 37, Loss G:  4.3160,Loss D:  0.0351
# Epoch 38, Loss G:  4.3106,Loss D:  0.0269
# Epoch 39, Loss G:  4.3068,Loss D: -0.0062
# Epoch 40, Loss G:  4.2778,Loss D: -0.0327
# Epoch 41, Loss G:  4.3097,Loss D: -0.0144
# Epoch 42, Loss G:  4.2422,Loss D: -0.0326
# Epoch 43, Loss G:  4.2820,Loss D: -0.0294
# Epoch 44, Loss G:  4.2626,Loss D: -0.0173
# Epoch 45, Loss G:  4.1976,Loss D: -0.0118
# Epoch 46, Loss G:  4.2009,Loss D:  0.0123
# Epoch 47, Loss G:  4.1604,Loss D: -0.0130
# Epoch 48, Loss G:  4.1421,Loss D:  0.0457
# Epoch 49, Loss G:  4.0995,Loss D:  0.0416
# Epoch 50, Loss G:  4.0903,Loss D:  0.0487
# Epoch 51, Loss G:  4.0678,Loss D:  0.0693
# Epoch 52, Loss G:  4.0383,Loss D:  0.0422
# Epoch 53, Loss G:  3.9793,Loss D:  0.0808
# Epoch 54, Loss G:  4.0230,Loss D:  0.0869
# Epoch 55, Loss G:  3.9786,Loss D:  0.0518
# Epoch 56, Loss G:  4.0013,Loss D:  0.0857
# Epoch 57, Loss G:  3.9440,Loss D:  0.0700
# Epoch 58, Loss G:  3.9182,Loss D:  0.0300
# Epoch 59, Loss G:  3.9557,Loss D:  0.0178
# Epoch 60, Loss G:  3.9289,Loss D:  0.0372
# Epoch 61, Loss G:  3.9162,Loss D: -0.0234
# Epoch 62, Loss G:  3.9298,Loss D: -0.0411
# Epoch 63, Loss G:  3.9342,Loss D: -0.0615
# Epoch 64, Loss G:  3.9392,Loss D: -0.0790
# Epoch 65, Loss G:  3.9467,Loss D: -0.1074
# Epoch 66, Loss G:  3.9012,Loss D: -0.0915
# Epoch 67, Loss G:  3.9294,Loss D: -0.0959
# Epoch 68, Loss G:  3.8514,Loss D: -0.0849
# Epoch 69, Loss G:  3.8298,Loss D: -0.0779
# Epoch 70, Loss G:  3.7717,Loss D: -0.0573
# Epoch 71, Loss G:  3.7286,Loss D: -0.0525
# Epoch 72, Loss G:  3.7156,Loss D: -0.0556
# Epoch 73, Loss G:  3.6367,Loss D: -0.0224
# Epoch 74, Loss G:  3.6085,Loss D: -0.0027
# Epoch 75, Loss G:  3.5892,Loss D:  0.0098
# Epoch 76, Loss G:  3.5090,Loss D: -0.0125
# Epoch 77, Loss G:  3.4927,Loss D:  0.0408
# Epoch 78, Loss G:  3.4432,Loss D:  0.0729
# Epoch 79, Loss G:  3.3886,Loss D:  0.0352
# Epoch 80, Loss G:  3.3530,Loss D:  0.0680
# Epoch 81, Loss G:  3.3007,Loss D:  0.0573
# Epoch 82, Loss G:  3.2997,Loss D:  0.0694
# Epoch 83, Loss G:  3.3024,Loss D:  0.0670
# Epoch 84, Loss G:  3.2480,Loss D:  0.0099
# Epoch 85, Loss G:  3.2163,Loss D:  0.0437
# Epoch 86, Loss G:  3.2401,Loss D:  0.0533
# Epoch 87, Loss G:  3.1211,Loss D:  0.0574
# Epoch 88, Loss G:  3.0227,Loss D:  0.0564
# Epoch 89, Loss G:  3.0058,Loss D:  0.1076
# Epoch 90, Loss G:  2.9861,Loss D:  0.0424
# Epoch 91, Loss G:  2.9726,Loss D:  0.0514
# Epoch 92, Loss G:  2.8782,Loss D:  0.0367
# Epoch 93, Loss G:  2.8576,Loss D:  0.0298
# Epoch 94, Loss G:  2.8132,Loss D:  0.0355
# Epoch 95, Loss G:  2.7573,Loss D:  0.0048
# Epoch 96, Loss G:  2.6869,Loss D:  0.0148
# Epoch 97, Loss G:  2.6803,Loss D:  0.0112
# Epoch 98, Loss G:  2.6209,Loss D: -0.0673
# Epoch 99, Loss G:  2.5571,Loss D: -0.0419
# Epoch 100, Loss G:  2.5288,Loss D: -0.0745
# Epoch 101, Loss G:  2.4635,Loss D: -0.0578
# Epoch 102, Loss G:  2.3969,Loss D: -0.0606
# Epoch 103, Loss G:  2.2555,Loss D: -0.0720
# Epoch 104, Loss G:  2.1991,Loss D: -0.0571
# Epoch 105, Loss G:  2.1664,Loss D: -0.0445
# Epoch 106, Loss G:  2.0374,Loss D: -0.0157
# Epoch 107, Loss G:  1.9494,Loss D: -0.0348
# Epoch 108, Loss G:  1.9272,Loss D: -0.0215
# Epoch 109, Loss G:  1.7935,Loss D:  0.0046
# Epoch 110, Loss G:  1.7876,Loss D:  0.0354
# Epoch 111, Loss G:  1.6700,Loss D:  0.0410
# Epoch 112, Loss G:  1.6066,Loss D:  0.0207
# Epoch 113, Loss G:  1.5041,Loss D:  0.0504
# Epoch 114, Loss G:  1.4447,Loss D:  0.0635
# Epoch 115, Loss G:  1.3104,Loss D:  0.0220
# Epoch 116, Loss G:  1.3021,Loss D:  0.0562
# Epoch 117, Loss G:  1.2573,Loss D:  0.0616
# Epoch 118, Loss G:  1.2370,Loss D:  0.0657
# Epoch 119, Loss G:  1.1545,Loss D:  0.0350
# Epoch 120, Loss G:  1.0521,Loss D:  0.0336
# Epoch 121, Loss G:  1.0817,Loss D:  0.0664
# Epoch 122, Loss G:  1.0713,Loss D:  0.0562
# Epoch 123, Loss G:  1.0300,Loss D: -0.0156
# Epoch 124, Loss G:  0.9511,Loss D: -0.0154
# Epoch 125, Loss G:  0.9288,Loss D: -0.0331
# Epoch 126, Loss G:  0.8950,Loss D: -0.0387
# Epoch 127, Loss G:  0.8787,Loss D: -0.0695
# Epoch 128, Loss G:  0.8277,Loss D: -0.0566
# Epoch 129, Loss G:  0.7794,Loss D: -0.0923
# Epoch 130, Loss G:  0.7563,Loss D: -0.0842
# Epoch 131, Loss G:  0.7074,Loss D: -0.0819
# Epoch 132, Loss G:  0.6777,Loss D: -0.0555
# Epoch 133, Loss G:  0.6482,Loss D: -0.0622
# Epoch 134, Loss G:  0.5915,Loss D: -0.0158
# Epoch 135, Loss G:  0.5563,Loss D: -0.0436
# Epoch 136, Loss G:  0.5651,Loss D: -0.0531
# Epoch 137, Loss G:  0.4684,Loss D: -0.0684
# Epoch 138, Loss G:  0.4297,Loss D: -0.0763
# Epoch 139, Loss G:  0.4363,Loss D: -0.0373
# Epoch 140, Loss G:  0.4098,Loss D: -0.0059
# Epoch 141, Loss G:  0.3733,Loss D:  0.0037
# Epoch 142, Loss G:  0.2656,Loss D:  0.0301
# Epoch 143, Loss G:  0.2329,Loss D:  0.0482
# Epoch 144, Loss G:  0.2017,Loss D:  0.0493
# Epoch 145, Loss G:  0.1724,Loss D:  0.0940
# Epoch 146, Loss G:  0.0728,Loss D:  0.0916
# Epoch 147, Loss G:  0.0714,Loss D:  0.1018
# Epoch 148, Loss G:  0.0516,Loss D:  0.1371
# Epoch 149, Loss G:  0.0079,Loss D:  0.1135
# Epoch 150, Loss G: -0.0050,Loss D:  0.1153

# %%
model.save(date_set_path + "100_models/" + "procedures_icd_model.pkl")

# %%
# model = CTGAN.load(("/content/drive/MyDrive/MSc Project/procedures_icd_model.pkl"))

# %%
sample = model.sample(num_rows=len(train_data))
# Out:
# Sampling rows: 100%|██████████| 490/490 [00:00<00:00, 13168.17it/s]

# %%
sample.head()
# Out:
#    subject_id  hadm_id  seq_num  icd9_code
# 0       49024   182358       12       3472
# 1       97158   152158        8       2825
# 2       31440   157693       10       2679
# 3       71297   111213        1       2817
# 4       19815   139461       10       2698

# %%
nan_count(sample)
# Out:
# Total columns: 4
# Total rows: 490
# --------------
# subject_id    0
# hadm_id       0
# seq_num       0
# icd9_code     0
# dtype: int64

# %%
sample.dtypes
# Out:
# subject_id    int64
# hadm_id       int64
# seq_num       int64
# icd9_code     int64
# dtype: object

# %%
evaluate(sample, train_data, metrics=['ContinuousKLDivergence'])
# Out:
# 0.33342425715442175

# %%
evaluate(sample, train_data, metrics=['DiscreteKLDivergence'])
# Out:
# nan

# %%
from sdv.sampling import Condition

# %%
admission_condition = Condition({
    'seq_num': 12
}, num_rows=10)

# %%
model.sample_conditions(conditions=admission_condition)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\MSc Project\Synthetic-Electronic-Health-Records-Data-using-MIMIC-III\SDV_procedures_icd_generation.ipynb Cell 35 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/f%3A/MSc%20Project/Synthetic-Electronic-Health-Records-Data-using-MIMIC-III/SDV_procedures_icd_generation.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> model.sample_conditions(conditions=admission_condition)
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\sdv\tabular\base.py:744, in BaseTabularModel.sample_conditions(self, conditions, max_tries_per_batch, batch_size, randomize_samples, output_file_path)
#     712 def sample_conditions(self, conditions, max_tries_per_batch=100, batch_size=None,
#     713                       randomize_samples=True, output_file_path=None):
#     714     """Sample rows from this table with the given conditions.
#     715
#     716     Args:
#    (...)
#     742                 * no rows could be generated.
#     743     """
# --> 744     return self._sample_conditions(
#     745         conditions, max_tries_per_batch, batch_size, randomize_samples, output_file_path)
#
# File d:\Environment\anaconda3\envs\msc_project\lib\site-packages\sdv\tabular\base.py:671, in BaseTabularModel._sample_conditions(self, conditions, max_tries_per_batch, batch_size, randomize_samples, output_file_path)
#     668 """Sample rows from this table with the given conditions."""
#     669 output_file_path = self._validate_file_path(output_file_path)
# --> 671 num_rows = functools.reduce(
#     672     lambda num_rows, condition: condition.get_num_rows() + num_rows, conditions, 0)
#     674 conditions = self._make_condition_dfs(conditions)
#     675 for condition_dataframe in conditions:
#
# TypeError: reduce() arg 2 must support iteration
